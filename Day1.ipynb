# %% [markdown]
# <a href="https://colab.research.google.com/github/danielazao/Python-3-Formation-complete/blob/master/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("votre message ici")
# Out:
# votre message ici

# %%
nom = input ("entre ton nom ")
age = input ("entre ton age ")
print("bonjour", nom ,"vous avez",age,"ans")
# Out:
# entre ton nom papy
# entre ton age 55
# bonjour papy vous avez 55 ans

# %%
print("le NOMBRE EST", 10)
print("5+5=",6+5)
# Out:
# le NOMBRE EST 10
# 5+5= 11

# %%
nom=("Daniel")
print(f"Hello,{nom}! Bienvenue à la programmation en python")
# Out:
# Hello,Daniel! Bienvenue à la programmation en python

# %%
nom_utilisateur=input("Quel est votre nom")
print(f"Hello,{nom_utilisateur}! Bienvenue à la programmation en python")
# Out:
# Quel est votre nomAZAO
# Hello,AZAO ! Bienvenue à la programmation en python

# %%
#Bienvenue dans notre générateur de message de bienvenue

#Etape 1: Demander les détails de l'utilisateur
nom_utilisateur=input("Quel est votre nom? ")
nom_utilisateur_up=nom_utilisateur.upper()
hobby=input("Quel est votre hobby? ")
hobby_up=hobby.upper()
couleur=input("Quel est votre couleur preferée? ")
couleur_up=couleur.upper()

#importation de la date du jours
from datetime import datetime

maintenant = datetime.now()
#print("Date et heure actuelles :", maintenant.strftime("%Y-%m-%d %H:%M:%S"))

#Formater du texte

#texte = input("Entrez un texte : ")
#texte_maj = texte.upper()
#print("En majuscule :", texte_maj)

#texte = input("Entrez un texte : ")
#texte_min = texte.lower()
#print("En minuscule :", texte_min)

#texte = input("Entrez un texte : ")
#texte_cap = texte.capitalize()
#print("Format phrase :", texte_cap)

#texte = input("Entrez un texte : ")
#texte_title = texte.title()
#print("Format titre :", texte_title)


#Etape 2: Générer le message personnalisé de bienvenue
print("\n---Message de bienvenue---")
print(f"la date du jours est:{maintenant}")
print(f"Bonjour {nom_utilisateur_up}!")
print(f"Bienvenue à la programmation en python.")
print(f"Votre hobby préféré est {hobby_up}.")
print(f"Votre couleur preferée est {couleur_up}")
# Out:
# Quel est votre nom? azao
# Quel est votre hobby? tenis
# Quel est votre couleur preferée? vert
#
# ---Message de bienvenue---
# la date du jours est:2026-01-30 10:15:14.070035
# Bonjour AZAO!
# Bienvenue à la programmation en python.
# Votre hobby préféré est TENIS.
# Votre couleur preferée est VERT
